# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas_datareader import data as wb

tickers = ['COF','DAL','BA','^DJI', '^GSPC', '^IXIC']

# %%
ret = pd.DataFrame()
for j in tickers:
    ret[j]= wb.DataReader(j,data_source='yahoo',start = '2021-1-1')['Adj Close']

# %%
ret
# Out:
#                    COF        DAL          BA          ^DJI        ^GSPC  \
# Date
# 2021-01-04   96.174301  38.730000  202.720001  30223.890625  3700.649902
# 2021-01-05   98.435143  39.549999  211.630005  30391.599609  3726.860107
# 2021-01-06  105.551880  40.380001  211.029999  30829.400391  3748.139893
# 2021-01-07  108.844849  40.230000  212.710007  31041.130859  3803.790039
# 2021-01-08  108.677734  40.020000  209.899994  31097.970703  3824.679932
# ...                ...        ...         ...           ...          ...
# 2021-12-09  149.169998  38.500000  207.559998  35754.691406  4667.450195
# 2021-12-10  150.410004  38.180000  205.059998  35970.988281  4712.020020
# 2021-12-13  146.039993  36.869999  197.399994  35650.949219  4668.970215
# 2021-12-14  147.919998  36.529999  195.500000  35544.179688  4634.089844
# 2021-12-15  147.389999  36.610001  195.429993  35927.429688  4709.850098
#
#                    ^IXIC
# Date
# 2021-01-04  12698.450195
# 2021-01-05  12818.959961
# 2021-01-06  12740.790039
# 2021-01-07  13067.480469
# 2021-01-08  13201.980469
# ...                  ...
# 2021-12-09  15517.370117
# 2021-12-10  15630.599609
# 2021-12-13  15413.280273
# 2021-12-14  15237.639648
# 2021-12-15  15565.583008
#
# [241 rows x 6 columns]

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
norm = ((ret/ret.iloc[0])*100).plot(figsize=(20,5))

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
ind_returns = (ret / ret.shift(1)) - 1

# %% [markdown]
# Estimate the average annual return of each index.

# %%
annual_ind_returns = ind_returns.mean() * 250

# %%
annual_ind_returns.plot(figsize = (18,5))
